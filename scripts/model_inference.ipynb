# %%
# load safetensors model
from safetensors.torch import load_file, load_model
from transformers import BertTokenizer
import torch

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# model = torch.nn.Module()

loaded = load_file("../models/claude_sent_model/model.safetensors")
load_model(model, "../models/claude_sent_model/model.safetensors")


test_lyrics = "I'm feeling happy today"
test_encodings = tokenizer(test_lyrics, padding=True, truncation=True)


print(model)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 11
#       8 # model = torch.nn.Module()
#      10 loaded = load_file("../models/claude_sent_model/model.safetensors")
# ---> 11 load_model(model, "../models/claude_sent_model/model.safetensors")
#      14 test_lyrics = "I'm feeling happy today"
#      15 test_encodings = tokenizer(test_lyrics, padding=True, truncation=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/safetensors/torch.py:219, in load_model(model, filename, strict, device)
#     217     if unexpected:
#     218         error += f"\n    Unexpected key(s) in state_dict: {unexpected_keys}"
# --> 219     raise RuntimeError(error)
#     220 return missing, unexpected
#
# RuntimeError: Error(s) in loading state_dict for Module:
# ...

# %%
from safetensors.torch import load_file
from transformers import BertTokenizer
import torch

# Load the model
model = BertModel.from_pretrained("../models/claude_sent_model/model.safetensors")

# Define the tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Define the input text
test_lyrics = ["I'm feeling happy today"]

# Tokenize the input text
test_encodings = tokenizer(test_lyrics, padding=True, truncation=True)

# Perform inference
with torch.no_grad():
    logits = model(**test_encodings)
    predictions = torch.argmax(logits, dim=1)
    print(predictions)
    print(logits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 19
#      17 # Perform inference
#      18 with torch.no_grad():
# ---> 19     logits = model(**test_encodings)
#      20     predictions = torch.argmax(logits, dim=1)
#      21     print(predictions)
#
# TypeError: 'dict' object is not callable

# %%
from transformers import BertModel

# Load the pretrained BERT model
model = BertModel.from_pretrained('bert-base-uncased')
